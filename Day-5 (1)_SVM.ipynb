# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import datasets       #iris dataset
from sklearn import svm            #svm algo
import matplotlib.pyplot as plt

# %%
iris_dataset=datasets.load_iris()
iris=pd.DataFrame(iris_dataset.data,columns=iris_dataset.feature_names)
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
sepal_length=iris_dataset['data'][:,0]
petal_length=iris_dataset['data'][:,2]

# %%
classes=iris_dataset['target']
plt.scatter(sepal_length,petal_length,c=classes)    #c ,not colour/color
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.show()

# %%
X=iris_dataset.data
y=iris_dataset.target

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X , y , test_size= 0.2)
#x_train x_test,y_train,y_test=sklearn.model_selection.train_test_split(X,y,test_size=0.2)
Edith=svm.SVC(kernel='linear') #poly,rbf
Edith.fit(x_train,y_train)
acc=Edith.score(x_test,y_test)
print(acc*100)
# Out:
# 100.0

# %%
predictions = Edith.predict(x_test)
for i in range(len(predictions)):
    print("Predicted value :",predictions[i],'Actual value :',y_test[i])
# Out:
# Predicted value : 2 Actual value : 2
# Predicted value : 0 Actual value : 0
# Predicted value : 1 Actual value : 1
# Predicted value : 1 Actual value : 1
# Predicted value : 1 Actual value : 1
# Predicted value : 2 Actual value : 2
# Predicted value : 0 Actual value : 0
# Predicted value : 0 Actual value : 0
# Predicted value : 2 Actual value : 2
# Predicted value : 2 Actual value : 2
# Predicted value : 0 Actual value : 0
# Predicted value : 1 Actual value : 1
# Predicted value : 1 Actual value : 1
# Predicted value : 1 Actual value : 1
# Predicted value : 1 Actual value : 1
# Predicted value : 1 Actual value : 1
# Predicted value : 1 Actual value : 1
# Predicted value : 2 Actual value : 2
# Predicted value : 2 Actual value : 2
# Predicted value : 2 Actual value : 2
# Predicted value : 2 Actual value : 2
# Predicted value : 2 Actual value : 2
# Predicted value : 2 Actual value : 2
# Predicted value : 0 Actual value : 0
# Predicted value : 2 Actual value : 2
# ...
